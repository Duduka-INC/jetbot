# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.22.4 in /Users/aleksandrterehin/venv/lib/python3.9/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/aleksandrterehin/venv/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/aleksandrterehin/venv/lib/python3.9/site-packages (from pandas) (2024.1)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/aleksandrterehin/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp39-cp39-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 11.4 MB/s eta 0:00:0000:0100:01
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 8.1 MB/s eta 0:00:0000:01
# Installing collected packages: tzdata, pandas
# Successfully installed pandas-2.2.2 tzdata-2024.1

# %%
marker_dict = cv.aruco.getPredefinedDictionary(cv.aruco.DICT_4X4_250)
param_markers = cv.aruco.DetectorParameters()
detector = cv.aruco.ArucoDetector(marker_dict, param_markers)

# %%
cap = cv.VideoCapture("rtsp://root:pass@192.168.0.94:554/mjpeg")

# %%
ret, frame = cap.read()
gray_frame = cv.cvtColor(frame, cv.COLOR_RGB2BGR)
plt.imshow(gray_frame)
print(ret)
print(type(frame))
# Out:
# True
# <class 'numpy.ndarray'>

# %%
(corners, ids, rejected) = detector.detectMarkers(gray_frame)
output_frame = cv.aruco.drawDetectedMarkers(gray_frame, corners, ids)
plt.imshow(output_frame)

# %%
# termination criteria
criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 30, 0.001)
 
# prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((6*8,3), np.float32)
objp[:,:2] = np.mgrid[0:8,0:6].T.reshape(-1,2)
 
# Arrays to store object points and image points from all the images.
objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane.
 
# images = glob.glob('Chess2.png')
images = output_frame
 
for i in range(1):
    img = output_frame
    # print("photo 1")
    # print(img)
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

    # Find the chess board corners
    ret, corners = cv.findChessboardCorners(gray, (8,6), None)

    # If found, add object points, image points (after refining them)
    if ret == True:
        objpoints.append(objp)

    corners2 = cv.cornerSubPix(gray,corners, (11,11), (-1,-1), criteria)
    imgpoints.append(corners2)

# Draw and display the corners
new_img = cv.drawChessboardCorners(img, (8,6), corners2, ret)
# print("photo 2")
# print(img)
plt.imshow(new_img)
plt.show()
# cv.imshow('Mar', img)
# cv.waitKey(0)
 
# cv.destroyAllWindows()

# %%
ret, mtx, dist, rvecs, tvecs = cv.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)

# %%
plt.imshow(frame)
# np.shape(frame)

# %%
# img = cv.imread('left12.jpg')
img = frame
h, w = img.shape[:2]
newcameramtx, roi = cv.getOptimalNewCameraMatrix(mtx, dist, (w,h), 1, (w,h))

# undistort
dst = cv.undistort(img, mtx, dist, None, newcameramtx)
 
# crop the image
x, y, w, h = roi
# print(np.shape(dst))
# dst = dst[y:y+h, x:x+w]
# print(h,w)
# print(np.shape(dst))
# cv.imwrite('calibresult.png', dst)
plt.imshow(dst)
cv.imwrite("filaname.png",dst)
# Out:
# True

# %%
img = frame
h, w = img.shape[:2]
newcameramtx, roi = cv.getOptimalNewCameraMatrix(mtx, dist, (w,h), 1, (w,h))
# undistort
mapx, mapy = cv.initUndistortRectifyMap(mtx, dist, None, newcameramtx, (w,h), 5)
dst = cv.remap(img, mapx, mapy, cv.INTER_LINEAR)
# crop the image
x, y, w, h = roi
# dst = dst[y:y+h, x:x+w]
# cv.imwrite('calibresult.png', dst)
plt.imshow(dst)
cv.imwrite("filaname.png",dst)
# Out:
# True

# %%
print(roi, mtx, dist, (w,h))

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=['id','name', 'occupation'])
# Out:
# roi       object
# mtx       object
# dist      object
# width      int64
# height     int64
# dtype: object

# %%
df = pd.dataFrame()

# %%
img = cv.imread('Chess 2.png')
cv.imshow('Mar', img)
cv.waitKey(0)

# %%
type(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 type(img)
#
# NameError: name 'img' is not defined

# %%
cv.imshow('img', img)
cv.waitKey(0)

# %%
while True:
    ret, frame = cap.read()
    if not ret:
        break
    # turning the frame to grayscale-only (for efficiency)
    gray_frame = cv.cvtColor(frame, cv.COLOR_RGB2BGR)
    marker_corners, marker_IDs, reject = detector.detectMarkers(gray_frame)
    # getting conrners of markers
    if marker_corners:
        for ids, corners in zip(marker_IDs, marker_corners):
            cv.polylines(
                gray_frame, [corners.astype(np.int32)], True, (0, 255, 255), 4, cv.LINE_AA
            )
            corners = corners.reshape(4, 2)
            corners = corners.astype(int)
            top_right = corners[0].ravel()
            top_left = corners[1].ravel()
            bottom_right = corners[2].ravel()
            bottom_left = corners[3].ravel()
            cv.putText(
                gray_frame,
                f"id: {ids[0]}",
                top_right,
                cv.FONT_HERSHEY_PLAIN,
                1.3,
                (200, 100, 0),
                2,
                cv.LINE_AA,
            )
            # print(ids, "  ", corners)
    plt.imshow("frame", gray_frame)
    key = cv.waitKey(1)
    if key == ord("q"):
        break
cap.release()
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <module>
#      20         cv.putText(
#      21             gray_frame,
#      22             f"id: {ids[0]}",
#    (...)
#      28             cv.LINE_AA,
#      29         )
#      30         # print(ids, "  ", corners)
# ---> 31 plt.imshow("frame", gray_frame)
#      32 key = cv.waitKey(1)
#      33 if key == ord("q"):
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:2671, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2664 @docstring.copy(Axes.imshow)
#    2665 def imshow(
#    2666         X, cmap=None, norm=None, aspect=None, interpolation=None,
#    (...)
#    2669         filterrad=4.0, imlim=cbook.deprecation._deprecated_parameter,
#    2670         resample=None, url=None, *, data=None, **kwargs):
# -> 2671     __ret = gca().imshow(
#    2672         X, cmap=cmap, norm=norm, aspect=aspect,
#    2673         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2674         vmax=vmax, origin=origin, extent=extent, shape=shape,
#    2675         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2676         resample=resample, url=url, **({"data": data} if data is not
#    2677         None else {}), **kwargs)
#    2678     sci(__ret)
#    2679     return __ret
#
# File /usr/lib/python3/dist-packages/matplotlib/__init__.py:1601, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1598 @functools.wraps(func)
#    1599 def inner(ax, *args, data=None, **kwargs):
#    1600     if data is None:
# -> 1601         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1603     bound = new_sig.bind(ax, *args, **kwargs)
#    1604     needs_label = (label_namer
#    1605                    and "label" not in bound.arguments
#    1606                    and "label" not in bound.kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/cbook/deprecation.py:369, in _delete_parameter.<locals>.wrapper(*args, **kwargs)
#     363 if name in arguments and arguments[name] != _deprecated_parameter:
#     364     warn_deprecated(
#     365         since, message=f"The {name!r} parameter of {func.__name__}() "
#     366         f"is deprecated since Matplotlib {since} and will be removed "
#     367         f"%(removal)s.  If any parameter follows {name!r}, they "
#     368         f"should be pass as keyword, not positionally.")
# --> 369 return func(*args, **kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/cbook/deprecation.py:369, in _delete_parameter.<locals>.wrapper(*args, **kwargs)
#     363 if name in arguments and arguments[name] != _deprecated_parameter:
#     364     warn_deprecated(
#     365         since, message=f"The {name!r} parameter of {func.__name__}() "
#     366         f"is deprecated since Matplotlib {since} and will be removed "
#     367         f"%(removal)s.  If any parameter follows {name!r}, they "
#     368         f"should be pass as keyword, not positionally.")
# --> 369 return func(*args, **kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:5675, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5673     aspect = rcParams['image.aspect']
#    5674 self.set_aspect(aspect)
# -> 5675 im = mimage.AxesImage(self, cmap, norm, interpolation, origin, extent,
#    5676                       filternorm=filternorm, filterrad=filterrad,
#    5677                       resample=resample, **kwargs)
#    5679 im.set_data(X)
#    5680 im.set_alpha(alpha)
#
# File /usr/lib/python3/dist-packages/matplotlib/image.py:855, in AxesImage.__init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, **kwargs)
#     839 """
#     840 interpolation and cmap default to their rc settings
#     841
#    (...)
#     850
#     851 """
#     853 self._extent = extent
# --> 855 super().__init__(
#     856     ax,
#     857     cmap=cmap,
#     858     norm=norm,
#     859     interpolation=interpolation,
#     860     origin=origin,
#     861     filternorm=filternorm,
#     862     filterrad=filterrad,
#     863     resample=resample,
#     864     **kwargs
#     865 )
#
# File /usr/lib/python3/dist-packages/matplotlib/image.py:207, in _ImageBase.__init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, **kwargs)
#     193 """
#     194 interpolation and cmap default to their rc settings
#     195
#    (...)
#     204
#     205 """
#     206 martist.Artist.__init__(self)
# --> 207 cm.ScalarMappable.__init__(self, norm, cmap)
#     208 self._mouseover = True
#     209 if origin is None:
#
# File /usr/lib/python3/dist-packages/matplotlib/cm.py:218, in ScalarMappable.__init__(self, norm, cmap)
#     216 self.norm = norm
#     217 #: The Colormap instance of this ScalarMappable.
# --> 218 self.cmap = get_cmap(cmap)
#     219 #: The last colorbar associated with this ScalarMappable. May be None.
#     220 self.colorbar = None
#
# File /usr/lib/python3/dist-packages/matplotlib/cm.py:175, in get_cmap(name, lut)
#     172 if isinstance(name, colors.Colormap):
#     173     return name
# --> 175 if name in cmap_d:
#     176     if lut is None:
#     177         return cmap_d[name]
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
from jetbot import Camera 
camera = Camera.instance()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/jetbot-0.4.0-py3.8.egg/jetbot/camera.py:30, in Camera.__init__(self, *args, **kwargs)
#      29 if not re:
# ---> 30     raise RuntimeError('Could not read image from camera.')
#      32 self.value = image
#
# RuntimeError: Could not read image from camera.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Input In [10], in <module>
#       1 from jetbot import Camera
# ----> 2 camera = Camera.instance()
#
# File /usr/local/lib/python3.8/dist-packages/traitlets/config/configurable.py:540, in SingletonConfigurable.instance(cls, *args, **kwargs)
#     538 # Create and save the instance
#     539 if cls._instance is None:
# --> 540     inst = cls(*args, **kwargs)
#     541     # Now make sure that the instance will also be returned by
#     542     # parent classes' _instance attribute.
#     543     for subclass in cls._walk_mro():
#
# File /usr/local/lib/python3.8/dist-packages/jetbot-0.4.0-py3.8.egg/jetbot/camera.py:36, in Camera.__init__(self, *args, **kwargs)
#      34 except:
#      35     self.stop()
# ---> 36     raise RuntimeError(
#      37         'Could not initialize camera.  Please see error trace.')
#      39 atexit.register(self.stop)
#
# RuntimeError: Could not initialize camera.  Please see error trace.
